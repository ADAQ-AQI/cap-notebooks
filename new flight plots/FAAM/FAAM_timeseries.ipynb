# %% [markdown]
# # Plot altitude profiles of aircraft pollution data

# %% [markdown]
# ## Setup imports

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import prep as pre

# %% [markdown]
# ## Define plotting function

# %%
def plot_altitude(x_data, y_data) :

    fig = plt.figure(figsize=(15,15))
    ax  = plt.axes([.2,.15,.75,.7])

    plt.plot(x_data,y_data,lw=5,c='cadetblue',label='Aircraft')

    plt.xlabel('Time / UTC',fontsize=50,labelpad=10)
    plt.ylabel(species_label,fontsize=50,labelpad=10)

    ax.xaxis.set_major_formatter(mdates.DateFormatter('%H:%m'))
    ax.tick_params(labelsize=30)

    plt.legend(fontsize=30,markerscale=2)

    plt.show()
    #plt.savefig(plotdir+species_key+'_Timeseries.png')
    #plt.close()

# %% [markdown]
# ## Prepare the data and plot for each pollution species

# %%
species_dict = pre.species_dictionary()
df = pre.data

for species in species_dict :
    species_key = species
    species_code = species_dict[species]['code']
    species_label = species_dict[species]['label']

    datetime_data = df.index
    conc_data = df[species_code][:].values

    plot_timeseries(datetime_data, conc_data)
